# %%
# %matplotlib inline
import time
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,Dataset
import matplotlib.pyplot as plt
import torchvision.utils
import numpy as np
import random
from PIL import Image
import torch
from torch.autograd import Variable
import PIL.ImageOps    
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
from model import *
from matplotlib.pyplot import imshow

# %%
DEFAULT_IMAGES_DIR = "scraper/images/training"
DEFAULT_BATCH_SIZE = 64
DEFAULT_NO_EPOCHS = 10
DEFAULT_MODEL_PATH = "model_cnn_full.h5"

# %%
class Config:
    def __init__(self, images_dir, batch_size, epochs, *args, **kwargs):
        self.images_dir = images_dir
        self.train_batch_size = batch_size
        self.train_number_epochs = epochs
        
config = Config(DEFAULT_IMAGES_DIR, DEFAULT_BATCH_SIZE, DEFAULT_NO_EPOCHS)

# %%
queryImage = Image.open('1.jpg')
plt.imshow(queryImage)

# %%
model = CNNQueryModel(DEFAULT_MODEL_PATH, classes='classes_full.csv')

# %%
start = time.time()
df = model.predict(queryImage)
end = time.time()
print(end-start)
# Out:
# 0.02692866325378418

# %%
df
# Out:
#        loss         file
# 0 -2.444570   138154.jpg
# 1 -2.420610   199149.jpg
# 2 -2.405692  1669864.jpg
# 3 -2.380592  1189855.jpg
# 4 -2.378181   223371.jpg
# 5 -2.368364  2363940.jpg
# 6 -2.361820   127891.jpg
# 7 -2.281991  2364229.jpg
# 8 -2.260210  1106876.jpg
# 9 -2.234231   227155.jpg

# %%
for file in df['file']:
    print(file)
    plt.figure()
    plt.imshow(Image.open('scraper/images/'+file))
# Out:
# 138154.jpg
# 199149.jpg
# 1669864.jpg
# 1189855.jpg
# 223371.jpg
# 2363940.jpg
# 127891.jpg
# 2364229.jpg
# 1106876.jpg
# 227155.jpg
